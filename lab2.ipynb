# %%
import lab2_gui

# %%
from importlib import reload
reload(lab2_gui)
# Out:
# <module 'lab2_gui' from 'D:\\Documents\\Projects\\RootDeep\\Labs SA\\lab2_gui.py'>

# %%
import tkinter as tk

# %%
root = tk.Tk()
lab_gui = lab2_gui.LabGUI(root)
root.mainloop()

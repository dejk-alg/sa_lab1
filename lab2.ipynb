# %%
import lab2_gui
import lab2_backend

# %%
import tkinter as tk

# %%
root = tk.Tk()
lab_gui = lab2_gui.LabGUI(root)
root.mainloop()
# Out:
# [ 154.621  398.163  587.411  767.197  966.547 1153.789 1210.926 1851.381
#  1987.364 2536.123]
# [3.71844 3.10009 3.31419 4.3464  4.38826 4.16044 4.01277 2.15176 3.157
#  2.37955]
# [ 154.621  398.163  587.411  767.197  966.547 1153.789 1210.926 1851.381
#  1987.364 2536.123]
